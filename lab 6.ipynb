# %%
import cv2
import numpy as np
import tensorflow as tf
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.utils import to_categorical
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Dropout
from PIL import Image
from keras.preprocessing import image

# %%
class otherModel:
    def __init__(self,  model=None):
        self.model = model

    def set_model(self, model):
        self.model = model
        
    def train_model(self, x_train, y_train, x_test, y_test, epochs=100, batch_size=200):
        y_train = to_categorical(y_train)
        y_test = to_categorical(y_test)
        self.model.fit(x_train, y_train, 
                    batch_size=batch_size, 
                    epochs=epochs,
                    validation_split=0.2, # Доля валидационной выборки для контроля переобучения
                    verbose=2) #verbose=0 ничего не покажет, verbose=1 покажет анимированный индикатор выполнения (progress_bar), verbose=2 будет просто указать номер эпохи

    def predict_dense(self, img):
            print("shape:", img.shape)  # Добавим вывод формы входных данных
            # Получаем вероятности для каждого класса
            probabilities = self.model.predict(img)
            # Используем argmax для получения индекса класса с наибольшей вероятностью
            return np.argmax(probabilities)

    def print_metrics(self):
        history_dict = self.model.history.history
        best_epoch = np.argmax(history_dict['val_accuracy']) + 1

        print("Метрики обучения:")
        print("---------------------------------------------------------")
        print(f"Максимальная точность на тренировочном наборе: {max(history_dict['accuracy']):.4f}")
        print(f"Минимальная потеря на тренировочном наборе: {min(history_dict['loss']):.4f}")
        print(f"Максимальная точность на валидационном наборе: {max(history_dict['val_accuracy']):.4f}")
        print(f"Минимальная потеря на валидационном наборе: {min(history_dict['val_loss']):.4f}")
        print(f"Наивысшая точность достигнута на эпохе: {best_epoch}")

# %%
class DenseModel:
    def __init__(self):
        self.model = None
        self.build_model()  # Инициализируем модель в конструкторе
        self.other_model = otherModel(self.model)  # Добавляем экземпляр класса otherModel
    
    def build_model(self, input_shape=(28, 28), num_classes=10):
        # Создаем последовательную модель нейронной сети
        self.model = Sequential()
        # Входной полносвязный слой
        # - 800 нейронов: определяет количество нейронов в слое
        # - input_dim=784: указывает на количество входов в каждый нейрон, в данном случае, 784, так как входные данные представляют собой изображения размером 28x28 пикселей, которые были преобразованы в одномерный массив размером 784 пикселя
        # - activation="relu": функция активации ReLU (Rectified Linear Unit) применяется для добавления нелинейности в сеть
        self.model.add(Dense(800, input_dim=784, activation="relu"))
        # Выходной полносвязный слой
        # - 10 нейронов: количество нейронов в выходном слое соответствует количеству классов, в данном случае, 10 классов (цифры от 0 до 9)
        # - activation="softmax": функция активации Softmax применяется для преобразования выходов сети в вероятности принадлежности к каждому классу
        self.model.add(Dense(10, activation="softmax"))
        # Компиляция модели
        # - loss="categorical_crossentropy": функция потерь, используемая для оценки ошибки сети; в данном случае, используется категориальная перекрестная энтропия, так как у нас задача классификации с несколькими классами
        # - optimizer="SGD": оптимизатор, используемый для обучения сети; в данном случае, используется стохастический градиентный спуск (SGD)
        # - metrics=["accuracy"]: метрики, используемые для оценки производительности сети во время обучения; в данном случае, используется метрика точности (accuracy)
        self.model.compile(loss="categorical_crossentropy", optimizer="SGD", metrics=["accuracy"])



    def train_model(self, x_train, y_train, x_test, y_test, epochs=100, batch_size=64):
        self.other_model.train_model(x_train, y_train, x_test, y_test, epochs, batch_size)  # Вызываем метод из класса otherModel

    def print_metrics(self):
        self.other_model.print_metrics()   # Вызываем метод из класса otherModel
    
    def transformation_img(self, img_path):
        img = image.load_img(img_path, target_size=(28, 28), color_mode="grayscale")
        # Преобразуем картинку в массив
        x = image.img_to_array(img)
        x = x.reshape(1,784)
        # Нормализуем изображение
        x = 255 - x
        x /= 255
        # Выпрямляем изображение в одномерный массив
        x = x.flatten()
        # Добавляем размерность батча (1, 784)
        x = np.expand_dims(x, axis=0)
        return x
    
    def predict_dense(self, img):
        print("Предсказанное число ", self.other_model.predict_dense(self.transformation_img(img)))

# %%
class ConvModel:
    def __init__(self):
        self.model = None
        self.build_model()  # Инициализируем модель в конструкторе
        self.other_model = otherModel(self.model)  # Добавляем экземпляр класса otherModel

    def build_model(self, input_shape=(28, 28, 1), num_classes=10):
        # Создаем последовательную модель нейронной сети
        self.model = Sequential()
        # Первый сверточный слой
        # 28 - количество фильтров, (3, 3) - размер ядра свертки, padding='same' - добавляет нулевые значения входам, чтобы размер выхода был таким же, как и у входа
        # input_shape=(28, 28, 1) - размерность входных данных (ширина, высота, количество каналов)
        # activation='relu' - функция активации ReLU (Rectified Linear Unit)
        self.model.add(Conv2D(28, (3, 3), padding='same', input_shape=(28, 28, 1), activation='relu'))
        # Второй сверточный слой
        # Аналогично первому слою, но без указания input_shape, так как это уже продолжение предыдущего слоя
        self.model.add(Conv2D(28, (3, 3), activation='relu', padding='same'))
        # Первый слой подвыборки
        # pool_size=(2, 2) - размер окна для уменьшения размерности
        self.model.add(MaxPooling2D(pool_size=(2, 2)))
        # Слой регуляризации Dropout
        # 0.25 - доля входных единиц, которые будут исключены случайным образом на каждом обновлении во время обучения для предотвращения переобучения
        self.model.add(Dropout(0.25))
        # Третий сверточный слой
        self.model.add(Conv2D(2 * 28, (3, 3), padding='same', activation='relu'))
        # Четвертый сверточный слой
        self.model.add(Conv2D(2 * 28, (3, 3), activation='relu'))
        # Второй слой подвыборки
        self.model.add(MaxPooling2D(pool_size=(2, 2)))
        # Слой регуляризации Dropout
        self.model.add(Dropout(0.25))
        # Слой преобразования данных из 2D представления в плоское
        self.model.add(Flatten())
        # Полносвязный слой для классификации
        # 8 * 28 - количество нейронов в слое
        self.model.add(Dense(8 * 28, activation='relu'))
        # Слой регуляризации Dropout
        self.model.add(Dropout(0.5))
        # Выходной полносвязный слой
        # 10 - количество классов для классификации
        self.model.add(Dense(10, activation='softmax'))
        # Компилируем модель
        # loss='categorical_crossentropy' - функция потерь для многоклассовой классификации
        # optimizer='adam' - оптимизатор Adam
        # metrics=['accuracy'] - метрика, используемая для оценки производительности модели
        self.model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])


    def transformation_img(self, img_path):
        img = image.load_img(img_path, target_size=(28, 28), color_mode="grayscale")
        # Преобразуем картинку в массив
        x = image.img_to_array(img)
        x= 255 - x
        # Нормализуем изображение
        x /= 255
        # для второй нейронки
        x = np.expand_dims(x, axis=0)
        return x
    
    def train_model(self, x_train, y_train, x_test, y_test, epochs=15, batch_size=64):
        self.other_model.train_model(x_train, y_train, x_test, y_test, epochs, batch_size)  # Вызываем метод из класса otherModel

    def print_metrics(self):
        self.other_model.print_metrics()   # Вызываем метод из класса otherModel
    
    def predict_dense(self, img):
        print("Предсказанное число (Dense Model):", self.other_model.predict_dense(self.transformation_img(img)))

# %%
# Загрузка данных MNIST
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Нормализация изображений
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
# Создание экземпляров классов моделей
dense_model = DenseModel()

# %%
conv_model = ConvModel()

# %%
# Обучение полносвязной нейронной сети
dense_model.build_model()

# Преобразуйте форму ваших входных данных
x_train_flat = x_train.reshape(x_train.shape[0], -1)
x_test_flat = x_test.reshape(x_test.shape[0], -1)

dense_model.train_model(x_train_flat, y_train, x_test_flat, y_test)
# Out:
# Epoch 1/100
# 750/750 - 8s - 10ms/step - accuracy: 0.8072 - loss: 0.8682 - val_accuracy: 0.8888 - val_loss: 0.4562
# Epoch 2/100
# 750/750 - 5s - 7ms/step - accuracy: 0.8901 - loss: 0.4245 - val_accuracy: 0.9076 - val_loss: 0.3546
# Epoch 3/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9027 - loss: 0.3561 - val_accuracy: 0.9139 - val_loss: 0.3145
# Epoch 4/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9109 - loss: 0.3219 - val_accuracy: 0.9206 - val_loss: 0.2911
# Epoch 5/100
# 750/750 - 8s - 10ms/step - accuracy: 0.9171 - loss: 0.2984 - val_accuracy: 0.9254 - val_loss: 0.2733
# Epoch 6/100
# 750/750 - 8s - 11ms/step - accuracy: 0.9220 - loss: 0.2805 - val_accuracy: 0.9277 - val_loss: 0.2598
# Epoch 7/100
# 750/750 - 7s - 9ms/step - accuracy: 0.9264 - loss: 0.2655 - val_accuracy: 0.9315 - val_loss: 0.2477
# Epoch 8/100
# 750/750 - 7s - 9ms/step - accuracy: 0.9303 - loss: 0.2525 - val_accuracy: 0.9341 - val_loss: 0.2377
# Epoch 9/100
# 750/750 - 7s - 9ms/step - accuracy: 0.9335 - loss: 0.2415 - val_accuracy: 0.9358 - val_loss: 0.2283
# Epoch 10/100
# 750/750 - 7s - 9ms/step - accuracy: 0.9359 - loss: 0.2310 - val_accuracy: 0.9386 - val_loss: 0.2209
# Epoch 11/100
# 750/750 - 10s - 14ms/step - accuracy: 0.9389 - loss: 0.2218 - val_accuracy: 0.9421 - val_loss: 0.2125
# Epoch 12/100
# 750/750 - 6s - 8ms/step - accuracy: 0.9407 - loss: 0.2132 - val_accuracy: 0.9442 - val_loss: 0.2058
# Epoch 13/100
# 750/750 - 7s - 9ms/step - accuracy: 0.9430 - loss: 0.2053 - val_accuracy: 0.9456 - val_loss: 0.1993
# Epoch 14/100
# 750/750 - 6s - 9ms/step - accuracy: 0.9447 - loss: 0.1981 - val_accuracy: 0.9477 - val_loss: 0.1936
# Epoch 15/100
# 750/750 - 6s - 8ms/step - accuracy: 0.9468 - loss: 0.1910 - val_accuracy: 0.9490 - val_loss: 0.1877
# Epoch 16/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9484 - loss: 0.1847 - val_accuracy: 0.9505 - val_loss: 0.1834
# Epoch 17/100
# 750/750 - 6s - 8ms/step - accuracy: 0.9498 - loss: 0.1787 - val_accuracy: 0.9521 - val_loss: 0.1781
# Epoch 18/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9516 - loss: 0.1731 - val_accuracy: 0.9533 - val_loss: 0.1733
# Epoch 19/100
# 750/750 - 6s - 8ms/step - accuracy: 0.9532 - loss: 0.1676 - val_accuracy: 0.9547 - val_loss: 0.1691
# Epoch 20/100
# 750/750 - 6s - 8ms/step - accuracy: 0.9544 - loss: 0.1627 - val_accuracy: 0.9555 - val_loss: 0.1658
# Epoch 21/100
# 750/750 - 6s - 8ms/step - accuracy: 0.9556 - loss: 0.1578 - val_accuracy: 0.9569 - val_loss: 0.1611
# Epoch 22/100
# 750/750 - 7s - 9ms/step - accuracy: 0.9572 - loss: 0.1534 - val_accuracy: 0.9572 - val_loss: 0.1580
# Epoch 23/100
# 750/750 - 6s - 8ms/step - accuracy: 0.9585 - loss: 0.1491 - val_accuracy: 0.9584 - val_loss: 0.1548
# Epoch 24/100
# 750/750 - 7s - 9ms/step - accuracy: 0.9597 - loss: 0.1451 - val_accuracy: 0.9597 - val_loss: 0.1517
# Epoch 25/100
# 750/750 - 6s - 9ms/step - accuracy: 0.9609 - loss: 0.1412 - val_accuracy: 0.9594 - val_loss: 0.1490
# Epoch 26/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9618 - loss: 0.1374 - val_accuracy: 0.9616 - val_loss: 0.1462
# Epoch 27/100
# 750/750 - 6s - 8ms/step - accuracy: 0.9628 - loss: 0.1339 - val_accuracy: 0.9622 - val_loss: 0.1430
# Epoch 28/100
# 750/750 - 7s - 9ms/step - accuracy: 0.9635 - loss: 0.1306 - val_accuracy: 0.9628 - val_loss: 0.1412
# Epoch 29/100
# 750/750 - 7s - 9ms/step - accuracy: 0.9647 - loss: 0.1275 - val_accuracy: 0.9626 - val_loss: 0.1393
# Epoch 30/100
# 750/750 - 6s - 8ms/step - accuracy: 0.9657 - loss: 0.1245 - val_accuracy: 0.9640 - val_loss: 0.1362
# Epoch 31/100
# 750/750 - 6s - 8ms/step - accuracy: 0.9663 - loss: 0.1214 - val_accuracy: 0.9636 - val_loss: 0.1349
# Epoch 32/100
# 750/750 - 6s - 8ms/step - accuracy: 0.9673 - loss: 0.1187 - val_accuracy: 0.9649 - val_loss: 0.1331
# Epoch 33/100
# 750/750 - 6s - 8ms/step - accuracy: 0.9684 - loss: 0.1161 - val_accuracy: 0.9644 - val_loss: 0.1308
# Epoch 34/100
# 750/750 - 7s - 9ms/step - accuracy: 0.9694 - loss: 0.1136 - val_accuracy: 0.9649 - val_loss: 0.1282
# Epoch 35/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9701 - loss: 0.1109 - val_accuracy: 0.9660 - val_loss: 0.1268
# Epoch 36/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9706 - loss: 0.1085 - val_accuracy: 0.9653 - val_loss: 0.1251
# Epoch 37/100
# 750/750 - 6s - 8ms/step - accuracy: 0.9713 - loss: 0.1063 - val_accuracy: 0.9666 - val_loss: 0.1235
# Epoch 38/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9719 - loss: 0.1041 - val_accuracy: 0.9666 - val_loss: 0.1225
# Epoch 39/100
# 750/750 - 11s - 15ms/step - accuracy: 0.9726 - loss: 0.1019 - val_accuracy: 0.9669 - val_loss: 0.1203
# Epoch 40/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9734 - loss: 0.0999 - val_accuracy: 0.9668 - val_loss: 0.1194
# Epoch 41/100
# 750/750 - 7s - 9ms/step - accuracy: 0.9740 - loss: 0.0979 - val_accuracy: 0.9680 - val_loss: 0.1176
# Epoch 42/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9747 - loss: 0.0960 - val_accuracy: 0.9684 - val_loss: 0.1161
# Epoch 43/100
# 750/750 - 6s - 8ms/step - accuracy: 0.9753 - loss: 0.0941 - val_accuracy: 0.9679 - val_loss: 0.1150
# Epoch 44/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9757 - loss: 0.0923 - val_accuracy: 0.9687 - val_loss: 0.1142
# Epoch 45/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9762 - loss: 0.0907 - val_accuracy: 0.9688 - val_loss: 0.1127
# Epoch 46/100
# 750/750 - 6s - 7ms/step - accuracy: 0.9767 - loss: 0.0890 - val_accuracy: 0.9689 - val_loss: 0.1115
# Epoch 47/100
# 750/750 - 6s - 7ms/step - accuracy: 0.9772 - loss: 0.0873 - val_accuracy: 0.9683 - val_loss: 0.1106
# Epoch 48/100
# 750/750 - 6s - 9ms/step - accuracy: 0.9779 - loss: 0.0857 - val_accuracy: 0.9697 - val_loss: 0.1092
# Epoch 49/100
# 750/750 - 6s - 8ms/step - accuracy: 0.9781 - loss: 0.0842 - val_accuracy: 0.9688 - val_loss: 0.1085
# Epoch 50/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9786 - loss: 0.0826 - val_accuracy: 0.9704 - val_loss: 0.1070
# Epoch 51/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9791 - loss: 0.0812 - val_accuracy: 0.9704 - val_loss: 0.1064
# Epoch 52/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9794 - loss: 0.0798 - val_accuracy: 0.9691 - val_loss: 0.1064
# Epoch 53/100
# 750/750 - 5s - 6ms/step - accuracy: 0.9797 - loss: 0.0784 - val_accuracy: 0.9706 - val_loss: 0.1043
# Epoch 54/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9802 - loss: 0.0771 - val_accuracy: 0.9711 - val_loss: 0.1035
# Epoch 55/100
# 750/750 - 10s - 13ms/step - accuracy: 0.9805 - loss: 0.0759 - val_accuracy: 0.9704 - val_loss: 0.1029
# Epoch 56/100
# 750/750 - 6s - 8ms/step - accuracy: 0.9806 - loss: 0.0746 - val_accuracy: 0.9711 - val_loss: 0.1019
# Epoch 57/100
# 750/750 - 6s - 8ms/step - accuracy: 0.9812 - loss: 0.0734 - val_accuracy: 0.9718 - val_loss: 0.1011
# Epoch 58/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9817 - loss: 0.0721 - val_accuracy: 0.9707 - val_loss: 0.1013
# Epoch 59/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9819 - loss: 0.0710 - val_accuracy: 0.9716 - val_loss: 0.0996
# Epoch 60/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9822 - loss: 0.0699 - val_accuracy: 0.9710 - val_loss: 0.0994
# Epoch 61/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9828 - loss: 0.0688 - val_accuracy: 0.9715 - val_loss: 0.0984
# Epoch 62/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9830 - loss: 0.0678 - val_accuracy: 0.9720 - val_loss: 0.0973
# Epoch 63/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9832 - loss: 0.0668 - val_accuracy: 0.9721 - val_loss: 0.0969
# Epoch 64/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9834 - loss: 0.0657 - val_accuracy: 0.9721 - val_loss: 0.0962
# Epoch 65/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9837 - loss: 0.0647 - val_accuracy: 0.9721 - val_loss: 0.0957
# Epoch 66/100
# 750/750 - 6s - 8ms/step - accuracy: 0.9843 - loss: 0.0636 - val_accuracy: 0.9722 - val_loss: 0.0954
# Epoch 67/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9845 - loss: 0.0627 - val_accuracy: 0.9732 - val_loss: 0.0942
# Epoch 68/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9847 - loss: 0.0618 - val_accuracy: 0.9727 - val_loss: 0.0942
# Epoch 69/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9851 - loss: 0.0609 - val_accuracy: 0.9730 - val_loss: 0.0938
# Epoch 70/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9850 - loss: 0.0600 - val_accuracy: 0.9732 - val_loss: 0.0928
# Epoch 71/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9857 - loss: 0.0592 - val_accuracy: 0.9728 - val_loss: 0.0922
# Epoch 72/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9855 - loss: 0.0583 - val_accuracy: 0.9737 - val_loss: 0.0920
# Epoch 73/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9856 - loss: 0.0575 - val_accuracy: 0.9738 - val_loss: 0.0913
# Epoch 74/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9860 - loss: 0.0567 - val_accuracy: 0.9740 - val_loss: 0.0910
# Epoch 75/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9862 - loss: 0.0559 - val_accuracy: 0.9743 - val_loss: 0.0903
# Epoch 76/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9866 - loss: 0.0551 - val_accuracy: 0.9742 - val_loss: 0.0898
# Epoch 77/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9866 - loss: 0.0544 - val_accuracy: 0.9746 - val_loss: 0.0894
# Epoch 78/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9871 - loss: 0.0536 - val_accuracy: 0.9746 - val_loss: 0.0891
# Epoch 79/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9874 - loss: 0.0529 - val_accuracy: 0.9742 - val_loss: 0.0891
# Epoch 80/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9875 - loss: 0.0522 - val_accuracy: 0.9746 - val_loss: 0.0886
# Epoch 81/100
# 750/750 - 6s - 8ms/step - accuracy: 0.9878 - loss: 0.0514 - val_accuracy: 0.9743 - val_loss: 0.0883
# Epoch 82/100
# 750/750 - 6s - 8ms/step - accuracy: 0.9881 - loss: 0.0507 - val_accuracy: 0.9752 - val_loss: 0.0878
# Epoch 83/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9881 - loss: 0.0501 - val_accuracy: 0.9753 - val_loss: 0.0871
# Epoch 84/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9883 - loss: 0.0494 - val_accuracy: 0.9748 - val_loss: 0.0871
# Epoch 85/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9888 - loss: 0.0488 - val_accuracy: 0.9748 - val_loss: 0.0868
# Epoch 86/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9886 - loss: 0.0482 - val_accuracy: 0.9753 - val_loss: 0.0866
# Epoch 87/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9889 - loss: 0.0475 - val_accuracy: 0.9758 - val_loss: 0.0853
# Epoch 88/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9890 - loss: 0.0469 - val_accuracy: 0.9754 - val_loss: 0.0856
# Epoch 89/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9895 - loss: 0.0463 - val_accuracy: 0.9756 - val_loss: 0.0857
# Epoch 90/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9894 - loss: 0.0458 - val_accuracy: 0.9756 - val_loss: 0.0847
# Epoch 91/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9896 - loss: 0.0452 - val_accuracy: 0.9750 - val_loss: 0.0852
# Epoch 92/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9899 - loss: 0.0446 - val_accuracy: 0.9754 - val_loss: 0.0842
# Epoch 93/100
# 750/750 - 6s - 8ms/step - accuracy: 0.9899 - loss: 0.0441 - val_accuracy: 0.9759 - val_loss: 0.0843
# Epoch 94/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9899 - loss: 0.0435 - val_accuracy: 0.9759 - val_loss: 0.0835
# Epoch 95/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9901 - loss: 0.0430 - val_accuracy: 0.9760 - val_loss: 0.0835
# Epoch 96/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9903 - loss: 0.0425 - val_accuracy: 0.9761 - val_loss: 0.0832
# Epoch 97/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9906 - loss: 0.0419 - val_accuracy: 0.9763 - val_loss: 0.0830
# Epoch 98/100
# 750/750 - 5s - 7ms/step - accuracy: 0.9907 - loss: 0.0415 - val_accuracy: 0.9762 - val_loss: 0.0827
# Epoch 99/100
# 750/750 - 6s - 8ms/step - accuracy: 0.9909 - loss: 0.0409 - val_accuracy: 0.9755 - val_loss: 0.0824
# Epoch 100/100
# 750/750 - 6s - 7ms/step - accuracy: 0.9911 - loss: 0.0405 - val_accuracy: 0.9760 - val_loss: 0.0821

# %%
dense_model.print_metrics()
# Out:
# Метрики обучения:
# ---------------------------------------------------------
# Максимальная точность на тренировочном наборе: 0.9911
# Минимальная потеря на тренировочном наборе: 0.0405
# Максимальная точность на валидационном наборе: 0.9763
# Минимальная потеря на валидационном наборе: 0.0821
# Наивысшая точность достигнута на эпохе: 97

# %%
def dense(path):
    dense_model.predict_dense(path)

# %%
dense('number/0.jpg')
dense('number/1.jpg')
dense('number/2.jpg')
dense('number/3.jpg')
dense('number/4.jpg')
# Out:
# shape: (1, 784)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Предсказанное число  0
# shape: (1, 784)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Предсказанное число  6
# shape: (1, 784)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Предсказанное число  2
# shape: (1, 784)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Предсказанное число  3
# shape: (1, 784)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Предсказанное число  4

# %%
dense('number/5.jpg')
dense('number/6.jpg')
dense('number/7.jpg')
dense('number/8.jpg')
dense('number/9.jpg')
# Out:
# shape: (1, 784)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# Предсказанное число  5
# shape: (1, 784)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Предсказанное число  7
# shape: (1, 784)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Предсказанное число  2
# shape: (1, 784)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# Предсказанное число  5
# shape: (1, 784)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# Предсказанное число  3

# %%
# Изменение формы входных данных для сверточной сети
x_train_conv = x_train.reshape(-1, 28, 28, 1)
x_test_conv = x_test.reshape(-1, 28, 28, 1)

# Обучение сверточной нейронной сети
conv_model.build_model()

# %%
conv_model.train_model(x_train_conv, y_train, x_test_conv, y_test)
# Out:
# Epoch 1/15
# 750/750 - 64s - 85ms/step - accuracy: 0.9251 - loss: 0.2361 - val_accuracy: 0.9847 - val_loss: 0.0545
# Epoch 2/15
# 750/750 - 68s - 91ms/step - accuracy: 0.9757 - loss: 0.0758 - val_accuracy: 0.9875 - val_loss: 0.0432
# Epoch 3/15
# 750/750 - 66s - 88ms/step - accuracy: 0.9822 - loss: 0.0571 - val_accuracy: 0.9905 - val_loss: 0.0346
# Epoch 4/15
# 750/750 - 62s - 83ms/step - accuracy: 0.9857 - loss: 0.0471 - val_accuracy: 0.9923 - val_loss: 0.0280
# Epoch 5/15
# 750/750 - 61s - 81ms/step - accuracy: 0.9880 - loss: 0.0394 - val_accuracy: 0.9918 - val_loss: 0.0312
# Epoch 6/15
# 750/750 - 63s - 84ms/step - accuracy: 0.9881 - loss: 0.0374 - val_accuracy: 0.9918 - val_loss: 0.0292
# Epoch 7/15
# 750/750 - 62s - 82ms/step - accuracy: 0.9896 - loss: 0.0330 - val_accuracy: 0.9933 - val_loss: 0.0257
# Epoch 8/15
# 750/750 - 71s - 95ms/step - accuracy: 0.9910 - loss: 0.0267 - val_accuracy: 0.9933 - val_loss: 0.0259
# Epoch 9/15
# 750/750 - 63s - 84ms/step - accuracy: 0.9915 - loss: 0.0274 - val_accuracy: 0.9935 - val_loss: 0.0266
# Epoch 10/15
# 750/750 - 94s - 126ms/step - accuracy: 0.9922 - loss: 0.0241 - val_accuracy: 0.9922 - val_loss: 0.0298
# Epoch 11/15
# 750/750 - 75s - 100ms/step - accuracy: 0.9925 - loss: 0.0240 - val_accuracy: 0.9929 - val_loss: 0.0263
# Epoch 12/15
# 750/750 - 75s - 100ms/step - accuracy: 0.9934 - loss: 0.0211 - val_accuracy: 0.9939 - val_loss: 0.0237
# Epoch 13/15
# 750/750 - 76s - 101ms/step - accuracy: 0.9932 - loss: 0.0205 - val_accuracy: 0.9928 - val_loss: 0.0283
# Epoch 14/15
# 750/750 - 70s - 93ms/step - accuracy: 0.9933 - loss: 0.0199 - val_accuracy: 0.9923 - val_loss: 0.0317
# Epoch 15/15
# 750/750 - 65s - 86ms/step - accuracy: 0.9940 - loss: 0.0182 - val_accuracy: 0.9939 - val_loss: 0.0261

# %%
conv_model.print_metrics()
# Out:
# Метрики обучения:
# ---------------------------------------------------------
# Максимальная точность на тренировочном наборе: 0.9940
# Минимальная потеря на тренировочном наборе: 0.0182
# Максимальная точность на валидационном наборе: 0.9939
# Минимальная потеря на валидационном наборе: 0.0237
# Наивысшая точность достигнута на эпохе: 12

# %%
def conv(path):
    conv_model.predict_dense(path)

# %%
img = cv2.imread('number/8.jpg')

# %%
conv('number/0.jpg')
conv('number/1.jpg')
conv('number/2.jpg')
conv('number/3.jpg')
conv('number/4.jpg')
# Out:
# shape: (1, 28, 28, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Предсказанное число (Dense Model): 0
# shape: (1, 28, 28, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Предсказанное число (Dense Model): 6
# shape: (1, 28, 28, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# Предсказанное число (Dense Model): 2
# shape: (1, 28, 28, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Предсказанное число (Dense Model): 3
# shape: (1, 28, 28, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# Предсказанное число (Dense Model): 4

# %%
conv('number/5.jpg')
conv('number/6.jpg')
conv('number/7.jpg')
conv('number/8.jpg')
conv('number/9.jpg')
# Out:
# shape: (1, 28, 28, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# Предсказанное число (Dense Model): 5
# shape: (1, 28, 28, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# Предсказанное число (Dense Model): 5
# shape: (1, 28, 28, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Предсказанное число (Dense Model): 7
# shape: (1, 28, 28, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Предсказанное число (Dense Model): 8
# shape: (1, 28, 28, 1)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Предсказанное число (Dense Model): 9
